# %%
from biogrid.db.manager import Importer

# Create an instance of the Importer class
importer = Importer(engine=None, file_path=None)

# Call the method and print the result
normalized = importer._normalize_column_names(columns)
print(normalized)
# Out:
# ['biogrid_interaction_id', 'official_symbol_interactor_a', 'experimental_system']

# %%
from biogrid.db.manager import Importer 
importer = Importer()
importer.recreate_db()  # Ensure tables are created
importer.import_data()
